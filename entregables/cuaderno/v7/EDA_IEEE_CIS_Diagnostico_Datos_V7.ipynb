# %% [markdown]
# <div style="box-sizing:border-box;width:100%;margin:12px 0 26px;padding:38px 42px;border:1px solid rgba(255,255,255,.18);border-radius:24px;color:#f8fbff;font-family:Inter,'Segoe UI',Arial,sans-serif;background:radial-gradient(circle at 92% 8%,rgba(255,255,255,.16) 0 8%,transparent 9%),linear-gradient(125deg,#102a43 0%,#184e77 56%,#2a9d8f 100%);box-shadow:0 16px 38px rgba(16,42,67,.28);overflow:hidden;">
#
#   <div style="display:flex;flex-wrap:wrap;gap:8px;margin:0 0 18px;">
#     <span style="display:inline-block;padding:6px 13px;border:1px solid rgba(255,255,255,.34);border-radius:999px;background:rgba(255,255,255,.13);color:#fff;font-size:11px;font-weight:800;line-height:1.2;letter-spacing:.06em;text-transform:uppercase;">
#       Deep Learning
#     </span>
#     <span style="display:inline-block;padding:6px 13px;border:1px solid rgba(255,255,255,.34);border-radius:999px;background:rgba(255,255,255,.13);color:#fff;font-size:11px;font-weight:800;line-height:1.2;letter-spacing:.06em;text-transform:uppercase;">
#       Proyecto 1
#     </span>
#     <span style="display:inline-block;padding:6px 13px;border:1px solid rgba(255,255,255,.34);border-radius:999px;background:rgba(255,255,255,.13);color:#fff;font-size:11px;font-weight:800;line-height:1.2;letter-spacing:.06em;text-transform:uppercase;">
#       Versión 7
#     </span>
#     <span style="display:inline-block;padding:6px 13px;border:1px solid rgba(255,255,255,.34);border-radius:999px;background:rgba(255,255,255,.13);color:#fff;font-size:11px;font-weight:800;line-height:1.2;letter-spacing:.06em;text-transform:uppercase;">
#       EDA causal
#     </span>
#     <span style="display:inline-block;padding:6px 13px;border:1px solid rgba(255,255,255,.34);border-radius:999px;background:rgba(255,255,255,.13);color:#fff;font-size:11px;font-weight:800;line-height:1.2;letter-spacing:.06em;text-transform:uppercase;">
#       IEEE-CIS
#     </span>
#     <span style="display:inline-block;padding:6px 13px;border:1px solid rgba(255,255,255,.34);border-radius:999px;background:rgba(255,255,255,.13);color:#fff;font-size:11px;font-weight:800;line-height:1.2;letter-spacing:.06em;text-transform:uppercase;">
#       Grupo 1
#     </span>
#   </div>
#
#   <div style="max-width:1040px;margin:0 0 10px;color:#fff;font-size:37px;font-weight:800;line-height:1.16;letter-spacing:-.02em;">
#     Análisis exploratorio causal de IEEE-CIS
#   </div>
#
#   <div style="max-width:980px;margin:0;color:rgba(255,255,255,.88);font-size:20px;font-weight:400;line-height:1.5;">
#     Diagnóstico temporal y multivariado para orientar la selección de variables, evaluar correlación y PCA, estudiar la identidad secuencial y explicar el comportamiento de los modelos de la V7
#   </div>
#
#   <div style="width:72px;height:4px;margin:22px 0;background:linear-gradient(90deg,#e9b949,rgba(255,255,255,.85));border-radius:999px;"></div>
#
#   <div style="display:grid;grid-template-columns:repeat(auto-fit,minmax(205px,1fr));gap:12px;margin-top:4px;">
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Institución
#       </span>
#       Universidad del Valle de Guatemala
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Curso
#       </span>
#       Deep Learning y Sistemas Inteligentes
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Sección
#       </span>
#       Sección 30
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Docente
#       </span>
#       Kevin Recinos
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Integrantes
#       </span>
#       Wilson Alejandro Calderón Argueta
#       <span style="color:rgba(255,255,255,.68);font-weight:600;">· 22018</span>
#       <br>
#       Pablo Daniel Barillas Moreno
#       <span style="color:rgba(255,255,255,.68);font-weight:600;">· 22193</span>
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Fuente de datos
#       </span>
#       IEEE-CIS Fraud Detection
#       <br>
#       <span style="color:rgba(255,255,255,.68);font-size:12px;">
#         Vesta Corporation · Kaggle
#       </span>
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Conjunto analizado
#       </span>
#       590,540 transacciones
#       <br>
#       <span style="color:rgba(255,255,255,.68);font-size:12px;">
#         20,663 fraudes · prevalencia de 3.50 %
#       </span>
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Alcance del EDA
#       </span>
#       Calidad, señal, ruido, deriva temporal, identidad proxy, correlación y reducción dimensional
#     </div>
#     <div style="min-width:0;padding:14px 16px;border:1px solid rgba(255,255,255,.25);border-radius:12px;background:rgba(255,255,255,.09);color:rgba(255,255,255,.96);font-size:13px;line-height:1.55;">
#       <span style="display:block;margin-bottom:5px;color:rgba(255,255,255,.7);font-size:10px;font-weight:800;letter-spacing:.09em;text-transform:uppercase;">
#         Control metodológico
#       </span>
#       Asociación, imputación, correlación y PCA ajustados únicamente con entrenamiento
#     </div>
#   </div>
#
#   <div style="margin-top:16px;padding:12px 15px;border:1px solid rgba(233,185,73,.42);border-left:4px solid #e9b949;border-radius:10px;background:rgba(7,25,39,.22);color:rgba(255,255,255,.88);font-size:12px;line-height:1.55;">
#     <strong style="color:#fff;">Alcance inferencial:</strong>
#     el último 15 % del conjunto corresponde a un benchmark temporal histórico reutilizado. Las decisiones de la V7 se realizan dentro del período de desarrollo; una afirmación confirmatoria requiere una cohorte futura etiquetada.
#   </div>
#
# </div>

# %% [markdown]
# <div class="section"><h2>1 · Alcance del EDA</h2></div>
# <div class="call"><b>Fuente:</b> <a href="https://www.kaggle.com/competitions/ieee-fraud-detection/overview">IEEE-CIS Fraud Detection</a>, datos anonimizados proporcionados por Vesta Corporation. El EDA global se limita a estructura y calidad; toda conclusión que puede cambiar el modelo —asociación con `isFraud`, correlación, selección, imputación y PCA— se calcula solo en train.</div>
# <div class="call warn"><b>Riesgo evitado:</b> observar correlaciones con el target o ajustar PCA en validación/test contaminaría la estimación temporal aunque no se entrene una red con esas etiquetas.</div>

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import HTML, display, Image

def find_root(start=Path.cwd()):
    for candidate in [start, *start.parents]:
        if (candidate / 'artefactos' / 'v7' / 'resultados_v7.json').exists():
            return candidate
    raise FileNotFoundError('Ejecute el notebook dentro del repositorio con artefactos/v7 disponibles.')

ROOT = find_root()
ART = ROOT / 'artefactos' / 'v7'
FIG = ROOT / 'evidencia' / 'figuras' / 'v7'
PROCESSED = ROOT / 'datos' / 'processed' / 'v7'
R = json.loads((ART / 'resultados_v7.json').read_text(encoding='utf-8'))
pd.set_option('display.max_colwidth', 90)
print(f'Raíz verificada: {ROOT}')
print(f"Versión: {R['version']} · filas: {R['datos']['filas']:,} · prevalencia: {R['datos']['prevalencia']:.3%}")
# Out:
# Raíz verificada: C:\Users\Daniel Barillas\Desktop\Lab-3_Deep-Learning\v7_implementation
# Versión: 7.0 · filas: 590,540 · prevalencia: 3.499%

# %% [markdown]
# <div class="section"><h2>2 · Inventario y exclusiones</h2></div>

# %%
audit = json.loads((PROCESSED / 'auditoria_variables_v7.json').read_text(encoding='utf-8'))
inv = audit['inventario']
display(pd.DataFrame({'Indicador':['Columnas de la unión','Candidatas sin target/ID/tiempo','Retenidas','Numéricas','Categóricas'], 'Valor':[inv['columnas_crudas_union'],inv['candidatas_sin_id_tiempo_target'],inv['retenidas'],inv['numericas'],inv['categoricas']]}))
print('Eliminadas por >99.5% faltantes:', ', '.join(inv['eliminadas_faltantes_gt_99_5']) or 'ninguna')
print('Eliminadas por constancia en train:', ', '.join(inv['eliminadas_constantes_train']) or 'ninguna')
assert 'TransactionID' not in json.loads((ART/'contrato_entrada_salida_v7.json').read_text(encoding='utf-8'))['entrada']['variables']
# Out:
#                          Indicador  Valor
# 0             Columnas de la unión    465
# 1  Candidatas sin target/ID/tiempo    462
# 2                        Retenidas    460
# 3                        Numéricas    423
# 4                      Categóricas     37
# Eliminadas por >99.5% faltantes: ninguna
# Eliminadas por constancia en train: C_missing_v7, V107

# %% [markdown]
# <div class="section"><h2>3 · Desbalance y deriva temporal</h2></div>

# %%
parts = pd.DataFrame(R['datos']['particiones']).T
display(parts[['n','prevalencia','dt_min','dt_max']].style.format({'n':'{:,.0f}','prevalencia':'{:.3%}','dt_min':'{:,.0f}','dt_max':'{:,.0f}'}))
fig, ax = plt.subplots(figsize=(8,4)); ax.bar(parts.index, parts['prevalencia']*100, color=['#184e77','#2a9d8f','#e9c46a']); ax.set(ylabel='Fraude (%)', title='Prevalencia por período temporal'); ax.tick_params(axis='x', rotation=10); plt.show()
print('La prevalencia baja confirma que accuracy no debe ser la métrica principal.')
# Out:
# <style type="text/css">
# </style>
# <table id="T_09ad4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09ad4_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_09ad4_level0_col1" class="col_heading level0 col1" >prevalencia</th>
#       <th id="T_09ad4_level0_col2" class="col_heading level0 col2" >dt_min</th>
#       <th id="T_09ad4_level0_col3" class="col_heading level0 col3" >dt_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09ad4_level0_row0" class="row_heading level0 row0" >train</th>
#       <td id="T_09ad4_row0_col0" class="data row0 col0" >413,378</td>
#       <td id="T_09ad4_row0_col1" class="data row0 col1" >3.517%</td>
#       <td id="T_09ad4_row0_col2" class="data row0 col2" >86,400</td>
#       <td id="T_09ad4_row0_col3" class="data row0 col3" >10,437,996</td>
#     </tr>
#     <tr>
#       <th id="T_09ad4_level0_row1" class="row_heading level0 row1" >validation</th>
# ...

# %% [markdown]
# <div class="section"><h2>4 · Identidad proxy y cobertura de historia</h2></div>

# %%
ident = pd.DataFrame(R['identidades']).T
cols = ['entidades','mediana_transacciones_entidad','p90_transacciones_entidad','porcentaje_con_3','porcentaje_con_8','porcentaje_con_16','porcentaje_con_32','porcentaje_campos_faltantes']
display(ident[cols].style.format({c:'{:.2f}' for c in cols}).background_gradient(cmap='Blues', subset=['porcentaje_con_3','porcentaje_con_8','porcentaje_con_16','porcentaje_con_32']))
display(HTML('<div class="call"><b>Lectura:</b> más cobertura no garantiza identidad correcta. Las claves con dispositivo pueden fragmentar un mismo cliente y las claves de tarjeta/dirección pueden mezclar personas. Esto limita la capacidad de B para aprender orden auténtico.</div>'))
# Out:
# <style type="text/css">
# #T_de82f_row0_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_de82f_row0_col4 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_de82f_row0_col5 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_de82f_row0_col6 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_de82f_row1_col3, #T_de82f_row1_col4, #T_de82f_row1_col5, #T_de82f_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_de82f_row2_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_de82f_row2_col4 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_de82f_row2_col5 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_de82f_row2_col6 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_de82f_row3_col3, #T_de82f_row3_col4, #T_de82f_row3_col5, #T_de82f_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de82f">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# <div class="section"><h2>5 · Asociación train-only</h2></div>
# La asociación point-biserial absoluta se usa como diagnóstico y para limitar costos de CatBoost/logística. No se interpreta causalmente: una variable puede correlacionarse con fraude por mezcla de segmentos, faltantes o cambios temporales.

# %%
assoc = pd.read_csv(PROCESSED/'asociacion_variables_train_v7.csv')
display(assoc.head(25).style.format({'asociacion_point_biserial_abs_train':'{:.4f}'}).bar(subset=['asociacion_point_biserial_abs_train'], color='#2a9d8f'))
top = assoc.head(20).sort_values('asociacion_point_biserial_abs_train')
fig, ax = plt.subplots(figsize=(8,6)); ax.barh(top['variable'], top['asociacion_point_biserial_abs_train'], color='#2a9d8f'); ax.set(xlabel='|asociación| en train', title='Variables más asociadas dentro de train'); plt.show()
# Out:
# <style type="text/css">
# #T_5165d_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 100.0%, transparent 100.0%);
# }
# #T_5165d_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 98.6%, transparent 98.6%);
# }
# #T_5165d_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 97.8%, transparent 97.8%);
# }
# #T_5165d_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 94.4%, transparent 94.4%);
# }
# #T_5165d_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 88.7%, transparent 88.7%);
# }
# #T_5165d_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 87.1%, transparent 87.1%);
# }
# #T_5165d_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 85.2%, transparent 85.2%);
# }
# #T_5165d_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2a9d8f 83.3%, transparent 83.3%);
# }
# #T_5165d_row8_col1 {
# ...

# %% [markdown]
# <div class="section"><h2>6 · Redundancia por correlación</h2></div>

# %%
corr = pd.read_csv(PROCESSED/'pares_correlacionados_train_v7.csv')
print(f"Pares con |rho_s| >= {R['variables']['correlacion']['umbral']}: {len(corr):,}")
display(corr.head(20).style.format({'rho_spearman_abs_train':'{:.4f}'}))
display(HTML('<div class="call proof"><b>Resultado:</b> eliminar redundancia extrema mejora AP en selección frente al LightGBM completo, pero esa ventaja no se sostiene por sí sola en evaluación. Correlación sirve para compactar; no garantiza generalización.</div>'))
# Out:
# Pares con |rho_s| >= 0.995: 34
# <style type="text/css">
# </style>
# <table id="T_ca781">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca781_level0_col0" class="col_heading level0 col0" >variable_1</th>
#       <th id="T_ca781_level0_col1" class="col_heading level0 col1" >variable_2</th>
#       <th id="T_ca781_level0_col2" class="col_heading level0 col2" >rho_spearman_abs_train</th>
#       <th id="T_ca781_level0_col3" class="col_heading level0 col3" >conservada</th>
#       <th id="T_ca781_level0_col4" class="col_heading level0 col4" >eliminada</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca781_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca781_row0_col0" class="data row0 col0" >V233</td>
#       <td id="T_ca781_row0_col1" class="data row0 col1" >V275</td>
#       <td id="T_ca781_row0_col2" class="data row0 col2" >0.9998</td>
# ...

# %% [markdown]
# <div class="section"><h2>7 · PCA: varianza frente a señal</h2></div>
# PCA encuentra componentes $\mathbf z=\mathbf W^\top(\mathbf x-\boldsymbol\mu)$ que maximizan varianza, no separación entre fraude y no fraude. Por eso se restringe al bloque anónimo V y se valida como ablation.

# %%
pca = audit['pca']; cumulative = np.array(pca['varianza_acumulada'])
summary = pd.DataFrame({'Corte':['90%','95%','99%','máximo ajustado'], 'Componentes':[pca['componentes_para_90'],pca['componentes_para_95'],pca['componentes_para_99'],pca['componentes_ajustados']]})
display(summary)
fig, ax = plt.subplots(figsize=(8,4)); ax.plot(np.arange(1,len(cumulative)+1), cumulative, color='#184e77'); ax.axhline(.95,ls='--',color='#e76f51'); ax.set(xlabel='Componentes',ylabel='Varianza explicada acumulada',title='PCA train-only del bloque V'); ax.grid(alpha=.2); plt.show()
display(Image(filename=str(FIG/'04_correlacion_pca_v7.png')))
# Out:
#              Corte  Componentes
# 0              90%           70
# 1              95%          105
# 2              99%          129
# 3  máximo ajustado          128

# %% [markdown]
# <div class="section"><h2>8 · Recomendaciones derivadas del EDA</h2></div>
# <table><thead><tr><th>Hallazgo</th><th>Implicación</th><th>Decisión V7</th></tr></thead><tbody>
# <tr><td>Alta dimensionalidad y categóricas</td><td>Una red mayor no corrige representación pobre</td><td>LightGBM, CatBoost y stacking</td></tr>
# <tr><td>Redundancia extrema localizada</td><td>Puede reducir costo computacional</td><td>Ablation Spearman, sin borrado ciego</td></tr>
# <tr><td>PCA conserva varianza, no necesariamente fraude</td><td>Debe validarse contra AP/costo</td><td>32/64/128 componentes solo en bloque V</td></tr>
# <tr><td>Identidad proxy imperfecta</td><td>Historia puede contener ruido</td><td>Falsificación de orden y longitudes 3/8/16/32</td></tr>
# <tr><td>Deriva entre ventanas</td><td>Una media oculta inestabilidad</td><td>Tres walk-forward y gate de cuatro ventanas</td></tr>
# </tbody></table>
# <div class="call"><b>Conclusión del EDA:</b> la mejora más defendible es combinar representaciones tabulares complementarias con el baseline fuerte. PCA y CatBoost no ganan individualmente; el orden sigue sin aportar señal material. La siguiente inversión debe ser una cohorte nueva e identidad más fiable.</div>
